# %% [markdown]
# # OPERADORES Y EXPRESIONES
#
# *** Los operadores y expresiones en Python son la base de cualquier programa: con ellos construimos condiciones, cálculos, decisiones y transformaciones.**

# %% [markdown]
# # OPERADORES ARITMETICOS
# ![image.png](attachment:image.png)

# %% [markdown]
# # OPERADORES DE COMPARACIÓN
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # OPERADORES LOGICOS
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # OPERADORES DE ASIGNACIÓN
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Operadores logicos
# pueden representar los valores Booleanos True y False

1 + 2 == 3 # True
1 + 10 != 11

# Tambien se tiene los operadores relacionales
# igual que 
3 == 3
# distinto de
10 != 5 # True

# mayor que
5 > 3 # True
# menor que
3 < 5 # True 

# mayor o igual que
5 >= 5 # True

# menor o igual que
3 <= 5 # True


# comparacion de variables 
a = 10
b = 5

a <= b # False
a > b # True
a == b # False
a != b # True

# combinacion de operadores logicos
# and (y)
valen = 500 
alex = 200

valen > 600 and alex > 100 
valen > 400 or  alex > 100 # True

# not (no)
not(valen > 600) # True
not(alex > 300) # True
not(alex < 300) # False
# Out:
# True
